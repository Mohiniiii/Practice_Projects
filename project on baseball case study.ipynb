# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#displaying the dataset
da=pd.read_csv("baseball.csv")
da
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
da.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # About the columns :

# %% [markdown]
# 1. Win: number of games where pitcher was pitching while their team took the lead and went on to win.

# %% [markdown]
# 2. R – Runs scored: times reached home plate legally and safely

# %% [markdown]
# 3. AB – At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.

# %% [markdown]
# 4. H – Hit: reaching base because of a batted, fair ball without error by the defense.

# %% [markdown]
# 5. 2B – Double: hits on which the batter reaches second base safely without the contribution of a fielding error.

# %% [markdown]
# 6. 3B – Triple: hits on which the batter reaches third base safely without the contribution of a fielding error.

# %% [markdown]
# 7. HR – Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.

# %% [markdown]
# 8. BB – Base on balls (also called a "walk"): hitter not swinging at four pitches called out of the strike zone and awarded first base.

# %% [markdown]
# 9. PA/SO – Plate appearances per strikeout: number of times a batter strikes out to their plate appearance

# %% [markdown]
# 10. SB – Stolen base: number of bases advanced by the runner while the ball is in the possession of the defense.

# %% [markdown]
# 11.RA – Run average: number of runs allowed times nine divided by innings pitched.

# %% [markdown]
# 12. ER – Earned run: number of runs that did not occur as a result of errors or passed balls.

# %% [markdown]
# 13. ERA – Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.

# %% [markdown]
# 14. CG – Complete game: number of games where player was the only pitcher for their team.

# %% [markdown]
# 15. SHO – Shutout: number of complete games pitched with no runs allowed.

# %% [markdown]
# 16. SV – Save: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.

# %% [markdown]
# 17. E – Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.

# %%
da.shape
# Out:
# (30, 17)

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
da.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# This shows that there are no null values in the dataset i.e in each and every column.

# %% [markdown]
# # Data preprocessing :

# %%
da.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
sns.pairplot(da, x_vars=['R','AB','H','2B','3B','HR','BB','SO'],y_vars=['W'],kind='scatter')
plt.show()

# %%
sns.pairplot(da,x_vars=['SB','RA','ER','ERA','CG','SHO','SV','E'],y_vars=['W'],kind='scatter')
plt.show()

# %% [markdown]
# From the above scatterplot, we can see that 'R','SO','SV' columns are least scattered hence, they are directly proportional to the Wins and the columns 'RA','ER','ERA' are scattered in a downward direction, hence they are inversely proportional to the wins. Rest of the columns are more scattered , let's check their correlation as well.

# %% [markdown]
# # Checking Correlation :

# %%
da.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
corr_mat=da.corr()
plt.figure(figsize=[10,10])
sns.heatmap(corr_mat, annot=False)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# for better explanation, let's have results of the above correlation in sorted manner.

# %%
corr_matrix=da.corr()
corr_matrix
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
type(corr_matrix)  #checking type of correlation matrix.
# Out:
# pandas.core.frame.DataFrame

# %%
corr_matrix=da.corr()
corr_matrix['W'].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.430751
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.080533
# H      0.037612
# AB    -0.087947
# E     -0.089485
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# Name: W, dtype: float64

# %% [markdown]
# The above depiction is to describe the correlation valuse of 'W'column which is the target variable also known as dependent variable with the independent variables. All those columns having positive values are having direct correlation with the target variable and those with negative values have indirect correlation . SV (save) is highly correlated and have positive correlation with Wins 'W'. ERA (earned runs) is negatively correlated with 'W'.

# %% [markdown]
# checking data distribution among all the columns :

# %%
da.plot(kind='density',subplots=True,layout=(6,11),sharex=False, legend=False, fontsize=1, figsize=(18,12))
plt.show()

# %% [markdown]
# We can see from above plots, that some of the columns are not normally distributed. They are not in their ideal shape. let's find their skewness to check how far the distribution of data is from their normal point.

# %% [markdown]
# Checking skewness :

# %%
#splitting data into dependent and independent variables :
x=da.drop("W",axis=1)
y=da["W"]

# %%
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# ...

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %% [markdown]
# # Checking Skewness :

# %%
#checking skewness
x.skew().sort_values(ascending=False)
# Out:
# R      1.200786
# E      0.890132
# CG     0.736845
# H      0.670254
# SV     0.657524
# SHO    0.565790
# HR     0.516441
# SB     0.479893
# AB     0.183437
# BB     0.158498
# 3B     0.129502
# ER     0.058710
# ERA    0.053331
# RA     0.045734
# SO    -0.156065
# 2B    -0.230650
# dtype: float64

# %%
#removing skewness using power_transform function
from sklearn.preprocessing import power_transform
x_new=power_transform(x)

# %%
type(x_new)
# Out:
# numpy.ndarray

# %%
x.columns
# Out:
# Index(['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA',
#        'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
x=pd.DataFrame(x_new,columns=x.columns)  #creating dataframe out of it using pandas since the type was numpy and only values will be taken.Because machine understands it better.

# %%
x
# Out:
#       R   AB    H        2B        3B        HR        BB        SO        SB  \
# 0   0.0  0.0  0.0  1.477685  1.033103 -0.764626 -1.610915 -2.569896  0.939708
# 1   0.0  0.0  0.0  0.084269  1.203320 -0.158581 -0.502749  0.134913 -0.539693
# 2   0.0  0.0  0.0  1.670782 -0.160270 -0.689676  1.128294 -0.901254  0.211956
# 3   0.0  0.0  0.0 -0.848600 -0.360521 -0.879049 -1.181207 -0.189628 -0.642564
# 4   0.0  0.0  0.0  0.792183  1.616444 -0.329850 -0.206771  0.085459  0.079629
# 5   0.0  0.0  0.0  1.998506 -1.461062  1.937860  1.708067 -0.957960  0.298238
# 6   0.0  0.0  0.0 -0.198558 -1.224911  1.460099  1.461121 -0.228668 -0.910154
# 7   0.0  0.0  0.0 -1.556454 -1.110302  1.583551 -0.904450  0.807174 -2.102897
# 8   0.0  0.0  0.0  0.141687  0.130611  0.200058 -0.559191  0.594561  0.255285
# 9   0.0  0.0  0.0  1.099405  0.225256  0.007404  0.204599 -0.986257 -0.489090
# 10  0.0  0.0  0.0  0.199390  0.130611  0.355503  0.634349 -0.170084  0.825451
# ...

# %%
x.skew().sort_values(ascending=False) #let's check whether skewness is removed or not using this method.
# Out:
# E      0.063909
# SO     0.041170
# SHO    0.006560
# ERA    0.001746
# SV     0.000836
# R      0.000000
# AB     0.000000
# H      0.000000
# HR    -0.000065
# ER    -0.001940
# BB    -0.007760
# RA    -0.008082
# SB    -0.010455
# 2B    -0.035315
# CG    -0.059785
# 3B    -0.072933
# dtype: float64

# %%
#let's save this skewness for future reference
sk=x.skew()

# %% [markdown]
# # Checking Outliers:

# %%
#plotting boxplots for outliers.
x.boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# We can above that there are some outliers in the columns SHO and E, but since they are very close to whiskers we will not consider them.

# %% [markdown]
# # Applying Variance Inflation Factor to reduce multicollinearity:

# %%
x
# Out:
#       R   AB    H        2B        3B        HR        BB        SO        SB  \
# 0   0.0  0.0  0.0  1.477685  1.033103 -0.764626 -1.610915 -2.569896  0.939708
# 1   0.0  0.0  0.0  0.084269  1.203320 -0.158581 -0.502749  0.134913 -0.539693
# 2   0.0  0.0  0.0  1.670782 -0.160270 -0.689676  1.128294 -0.901254  0.211956
# 3   0.0  0.0  0.0 -0.848600 -0.360521 -0.879049 -1.181207 -0.189628 -0.642564
# 4   0.0  0.0  0.0  0.792183  1.616444 -0.329850 -0.206771  0.085459  0.079629
# 5   0.0  0.0  0.0  1.998506 -1.461062  1.937860  1.708067 -0.957960  0.298238
# 6   0.0  0.0  0.0 -0.198558 -1.224911  1.460099  1.461121 -0.228668 -0.910154
# 7   0.0  0.0  0.0 -1.556454 -1.110302  1.583551 -0.904450  0.807174 -2.102897
# 8   0.0  0.0  0.0  0.141687  0.130611  0.200058 -0.559191  0.594561  0.255285
# 9   0.0  0.0  0.0  1.099405  0.225256  0.007404  0.204599 -0.986257 -0.489090
# 10  0.0  0.0  0.0  0.199390  0.130611  0.355503  0.634349 -0.170084  0.825451
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif_calc():
    vif=pd.DataFrame()
    vif["VIF Factor"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif["Features"]=x.columns
    print (vif)

# %%
vif_calc()
# Out:
#     VIF Factor Features
# 0          NaN        R
# 1          NaN       AB
# 2          NaN        H
# 3     2.221041       2B
# 4     2.697792       3B
# 5     2.867884       HR
# 6     3.331177       BB
# 7     2.321817       SO
# 8     1.888334       SB
# 9   177.760829       RA
# 10  543.300331       ER
# 11  314.143795      ERA
# 12    2.162372       CG
# 13    3.197808      SHO
# 14    3.518082       SV
# 15    1.711436        E

# %% [markdown]
# Since the highest value is for the columns "ER" , "ERA" and "RA", so we can think of dropping it along with R, AB and H since they have 0 as values.

# %%
x=da.drop(["ER","ERA", "RA","R","AB","H"],axis=1)

# %%
x
# Out:
#       W   2B  3B   HR   BB    SO   SB  CG  SHO  SV    E
# 0    95  300  42  139  383   973  104   2    8  56   88
# 1    83  277  44  156  439  1264   70   2   12  45   86
# 2    81  303  29  141  533  1157   86  11   10  38   79
# 3    76  260  27  136  404  1231   68   7    9  37  101
# 4    74  289  49  151  455  1259   83   7   12  35   86
# 5    93  308  17  232  570  1151   88   7   10  34   88
# 6    87  272  19  212  554  1227   63   3    4  48   93
# 7    81  246  20  217  418  1331   44   0   10  43   77
# 8    80  278  32  167  436  1310   87   1   12  60   95
# 9    78  294  33  161  478  1148   71   3   10  40   97
# 10   88  279  32  172  503  1233  101   5    9  45  119
# 11   86  278  26  230  486  1392  121   5   13  39   85
# 12   85  243  21  176  435  1150   52   2   12  46   93
# 13   76  262  22  198  478  1336   69   6   12  45   94
# 14   68  277  46  146  475  1119   78   5   15  28  126
# 15  100  288  39  137  506  1267   69   1   15  62   96
# ...

# %%
x.shape
# Out:
# (30, 16)

# %% [markdown]
# # Standard Scaling:

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score

# %%
scale=StandardScaler()  #standardizes features by removing the mean and scaling to unit variance
x=scale.fit_transform(x)
x
# Out:
# array([[ 0.61907797,  0.84773126,  1.66368512,  1.42017307,  1.04119304,
#         -0.7872986 , -1.53490242, -2.69762957,  0.91388329, -0.66623393,
#         -0.50511008, -0.50695519, -0.5398062 , -0.81462859,  1.67160651,
#         -0.46146963],
#        [ 0.13443166, -0.71109353, -0.97068076,  0.12740339,  1.23580856,
#         -0.24396668, -0.5365919 ,  0.15487844, -0.60182558,  0.16597077,
#          0.24892985,  0.25459752, -0.5398062 ,  0.1728    ,  0.24987932,
#         -0.60719689],
#        [-0.33290586, -1.1152333 , -0.15189137,  1.58879521, -0.22380785,
#         -0.7233772 ,  1.13914361, -0.89398189,  0.11144918, -0.68033909,
#         -0.75162313, -0.64134684,  2.77264091, -0.32091429, -0.65485616,
#         -1.11724227],
#        [-1.14641931,  0.24152162, -0.40108814, -0.82812203, -0.41842337,
#         -0.8831807 , -1.16053598, -0.16860185, -0.69098493,  0.18007593,
#          0.10392217,  0.05301004,  1.3004422 , -0.56777144, -0.78410408,
#          0.48575751],
# ...

# %%
x
# Out:
# array([[ 0.61907797,  0.84773126,  1.66368512,  1.42017307,  1.04119304,
#         -0.7872986 , -1.53490242, -2.69762957,  0.91388329, -0.66623393,
#         -0.50511008, -0.50695519, -0.5398062 , -0.81462859,  1.67160651,
#         -0.46146963],
#        [ 0.13443166, -0.71109353, -0.97068076,  0.12740339,  1.23580856,
#         -0.24396668, -0.5365919 ,  0.15487844, -0.60182558,  0.16597077,
#          0.24892985,  0.25459752, -0.5398062 ,  0.1728    ,  0.24987932,
#         -0.60719689],
#        [-0.33290586, -1.1152333 , -0.15189137,  1.58879521, -0.22380785,
#         -0.7233772 ,  1.13914361, -0.89398189,  0.11144918, -0.68033909,
#         -0.75162313, -0.64134684,  2.77264091, -0.32091429, -0.65485616,
#         -1.11724227],
#        [-1.14641931,  0.24152162, -0.40108814, -0.82812203, -0.41842337,
#         -0.8831807 , -1.16053598, -0.16860185, -0.69098493,  0.18007593,
#          0.10392217,  0.05301004,  1.3004422 , -0.56777144, -0.78410408,
#          0.48575751],
# ...

# %% [markdown]
# # Training the dataset:

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=30)

# %%
x_train.shape
# Out:
# (24, 16)

# %%
y_train.shape
# Out:
# (24,)

# %%
x_test.shape
# Out:
# (6, 16)

# %%
y_test.shape
# Out:
# (6,)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_   #as there are 16 columns
# Out:
# array([  7.27733977,  -1.07159861,   0.02776723,  -3.01321952,
#          1.46939518,  -1.14759122,  -1.59458772,   0.29163922,
#         -0.67788002,  19.99089689,  -3.76882703, -22.15154404,
#          2.4435404 ,   0.43730178,   5.35663505,  -1.59135672])

# %%
lm.intercept_
# Out:
# 80.64761583273797

# %%
da.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
lm.score(x_train,y_train)
# Out:
# 0.9494811939208996

# %%
pred=lm.predict(x_test)  #x_test will be sent for testing
print("Predicted Wins:", pred)
print("Actual Wins:", y_test)
# Out:
# Predicted Wins: [99.33886818 82.37436225 81.52842042 81.92145051 57.95115133 91.3142223 ]
# Actual Wins: 15    100
# 28     74
# 26     84
# 10     88
# 24     63
# 0      95
# Name: W, dtype: int64

# %%
print("error:")
print("Mean Absolute Error:", mean_absolute_error(y_test,pred))
print("Mean Squared Error:", mean_squared_error(y_test,pred))    # to check model accuracy
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error:
# Mean Absolute Error: 4.386708254056057
# Mean Squared Error: 25.45005636035991
# Root Mean Squared Error: 5.044804888235015

# %% [markdown]
# # Calculating r2 score to see how well the model fits the data:

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.8365092739163175

# %% [markdown]
# # Saving the final model since the model is working fine:

# %%
import joblib
#save the model as the object file

joblib.dump(lm, "lmfile.obj")
#load the model from the file and store in c -drive ( you can use any object name here i.e, instance name here of any particular file.
lm_from_joblib=joblib.load("lmfile.obj")

#use the loaded model to make predictions

lm_from_joblib.predict(x_test)
# Out:
# array([99.33886818, 82.37436225, 81.52842042, 81.92145051, 57.95115133,
#        91.3142223 ])
